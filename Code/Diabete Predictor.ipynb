# %% [markdown]
# # CSCE 585: Machine Learning Systems Final Project
#
# ## Project Title: Diabetes Prediction Using Machine Learning
#
# *Diabetes Mellitus* is among critical diseases and lots of people are suffering from it in recent years. According to the recent studies, age, obesity, lack of exercise, hereditary diabetes, living style, bad diet, high blood pressure, etc. can cause Diabetes Mellitus. People having diabetes have high risk of diseases such as heart disease, kidney disease, stroke, eye problem, and nerve damage. With the recent advancements in the field of machine learning (ML), several researchers have tried to apply ML models to perform Diabetes prediction in patients based on various factors. However, there is no rigorous and comprehensive study on the evaluation of different ML models to determine the best practices in this specific problem.
#
# In this project, we aim at implementing and evaluating different classification methods (e.g., decision tree, random forest, support vector machine, and neural network) on the given dataset and determine which methods perform better and under which conditions. We will use the Pima Indians onset of diabetes dataset. This is a standard machine learning dataset from the UCI Machine Learning repository. It describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
#
# Our dataset has the following features:
# * Number of Instances: 768
#
# * Number of Attributes: 8 plus class
#
# * For Each row in the dataset (all numeric-valued), we have the following columns:
#    * Number of times pregnant
#    * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#    * Diastolic blood pressure (mm Hg)
#    * Triceps skin fold thickness (mm)
#    * 2-Hour serum insulin (mu U/ml)
#    * Body mass index (weight in kg/(height in m)^2)
#    * Diabetes pedigree function
#    * Age (years)
#    * Class variable (0 or 1)

# %%
# import the necessary modules here!
import pandas as pd
import numpy as np
import matplotlib
import os

# %%
# form the path to the dataset 
current_path_str = os.getcwd()
current_path_list = current_path_str.split("/")
dataset_path_list = current_path_list[:-1]
dataset_path_list.append("Dataset")
dataset_path_str = "/".join(dataset_path_list)
path = dataset_path_str + "/diabetes.csv"

# load the dataset to pandas dataframe
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from pycaret.classification import *

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
experiment = setup(df, target="Outcome")
# Out:
# <style type="text/css">
# #T_d92f2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d92f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d92f2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d92f2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d92f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d92f2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d92f2_row0_col1" class="data row0 col1" >8253</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d92f2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d92f2_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d92f2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d92f2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d92f2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d92f2_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d92f2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d92f2_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d92f2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d92f2_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d92f2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d92f2_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d92f2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d92f2_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d92f2_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d92f2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d92f2_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d92f2_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d92f2_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d92f2_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d92f2_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d92f2_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d92f2_row12_col0" class="data row12 col0" >Low variance threshold</td>
#       <td id="T_d92f2_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d92f2_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_d92f2_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d92f2_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_d92f2_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d92f2_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_d92f2_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d92f2_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_d92f2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d92f2_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_d92f2_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d92f2_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_d92f2_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d92f2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d92f2_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_d92f2_row19_col1" class="data row19 col1" >46ff</td>
#     </tr>
#   </tbody>
# </table>

# %%
#setup??

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_32b9e th {
#   text-align: left;
# }
# #T_32b9e_row0_col0, #T_32b9e_row0_col2, #T_32b9e_row0_col3, #T_32b9e_row0_col5, #T_32b9e_row0_col6, #T_32b9e_row0_col7, #T_32b9e_row1_col0, #T_32b9e_row1_col1, #T_32b9e_row1_col3, #T_32b9e_row1_col4, #T_32b9e_row1_col5, #T_32b9e_row2_col0, #T_32b9e_row2_col1, #T_32b9e_row2_col2, #T_32b9e_row2_col3, #T_32b9e_row2_col4, #T_32b9e_row2_col5, #T_32b9e_row2_col6, #T_32b9e_row2_col7, #T_32b9e_row3_col0, #T_32b9e_row3_col1, #T_32b9e_row3_col2, #T_32b9e_row3_col3, #T_32b9e_row3_col4, #T_32b9e_row3_col5, #T_32b9e_row3_col6, #T_32b9e_row3_col7, #T_32b9e_row4_col0, #T_32b9e_row4_col1, #T_32b9e_row4_col2, #T_32b9e_row4_col4, #T_32b9e_row4_col6, #T_32b9e_row4_col7, #T_32b9e_row5_col0, #T_32b9e_row5_col1, #T_32b9e_row5_col2, #T_32b9e_row5_col3, #T_32b9e_row5_col4, #T_32b9e_row5_col5, #T_32b9e_row5_col6, #T_32b9e_row5_col7, #T_32b9e_row6_col0, #T_32b9e_row6_col1, #T_32b9e_row6_col2, #T_32b9e_row6_col3, #T_32b9e_row6_col4, #T_32b9e_row6_col5, #T_32b9e_row6_col6, #T_32b9e_row6_col7, #T_32b9e_row7_col0, #T_32b9e_row7_col1, #T_32b9e_row7_col2, #T_32b9e_row7_col3, #T_32b9e_row7_col4, #T_32b9e_row7_col5, #T_32b9e_row7_col6, #T_32b9e_row7_col7, #T_32b9e_row8_col0, #T_32b9e_row8_col1, #T_32b9e_row8_col2, #T_32b9e_row8_col3, #T_32b9e_row8_col4, #T_32b9e_row8_col5, #T_32b9e_row8_col6, #T_32b9e_row8_col7, #T_32b9e_row9_col0, #T_32b9e_row9_col1, #T_32b9e_row9_col2, #T_32b9e_row9_col3, #T_32b9e_row9_col4, #T_32b9e_row9_col5, #T_32b9e_row9_col6, #T_32b9e_row9_col7, #T_32b9e_row10_col0, #T_32b9e_row10_col1, #T_32b9e_row10_col2, #T_32b9e_row10_col3, #T_32b9e_row10_col4, #T_32b9e_row10_col5, #T_32b9e_row10_col6, #T_32b9e_row10_col7, #T_32b9e_row11_col0, #T_32b9e_row11_col1, #T_32b9e_row11_col2, #T_32b9e_row11_col3, #T_32b9e_row11_col4, #T_32b9e_row11_col5, #T_32b9e_row11_col6, #T_32b9e_row11_col7, #T_32b9e_row12_col0, #T_32b9e_row12_col1, #T_32b9e_row12_col2, #T_32b9e_row12_col3, #T_32b9e_row12_col4, #T_32b9e_row12_col5, #T_32b9e_row12_col6, #T_32b9e_row12_col7, #T_32b9e_row13_col0, #T_32b9e_row13_col1, #T_32b9e_row13_col2, #T_32b9e_row13_col3, #T_32b9e_row13_col4, #T_32b9e_row13_col5, #T_32b9e_row13_col6, #T_32b9e_row13_col7 {
#   text-align: left;
# }
# #T_32b9e_row0_col1, #T_32b9e_row0_col4, #T_32b9e_row1_col2, #T_32b9e_row1_col6, #T_32b9e_row1_col7, #T_32b9e_row4_col3, #T_32b9e_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_32b9e_row0_col8, #T_32b9e_row1_col8, #T_32b9e_row2_col8, #T_32b9e_row4_col8, #T_32b9e_row5_col8, #T_32b9e_row6_col8, #T_32b9e_row7_col8, #T_32b9e_row8_col8, #T_32b9e_row9_col8, #T_32b9e_row10_col8, #T_32b9e_row11_col8, #T_32b9e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T
>0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_32b9e_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_32b9e_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_32b9e_row5_col1" class="data row5 col1" >0.7506</td>
#       <td id="T_32b9e_row5_col2" class="data row5 col2" >0.8190</td>
#       <td id="T_32b9e_row5_col3" class="data row5 col3" >0.5561</td>
#       <td id="T_32b9e_row5_col4" class="data row5 col4" >0.6947</td>
#       <td id="T_32b9e_row5_col5" class="data row5 col5" >0.6077</td>
#       <td id="T_32b9e_row5_col6" class="data row5 col6" >0.4293</td>
#       <td id="T_32b9e_row5_col7" class="data row5 col7" >0.4418</td>
#       <td id="T_32b9e_row5_col8" c

# %%
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9845b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9845b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9845b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9845b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9845b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9845b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9845b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9845b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9845b_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9845b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9845b_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_9845b_row0_col1" class="data row0 col1" >0.8009</td>
#       <td id="T_9845b_row0_col2" class="data row0 col2" >0.8399</td>
#       <td id="T_9845b_row0_col3" class="data row0 col3" >0.6173</td>
#       <td id="T_9845b_row0_col4" class="data row0 col4" >0.7692</td>
#       <td id="T_9845b_row0_col5" class="data row0 col5" >0.6849</td>
#       <td id="T_9845b_row0_col6" class="data row0 col6" >0.5419</td>
#       <td id="T_9845b_row0_col7" class="data row0 col7" >0.5489</td>
#     </tr>
#   </tbody>
# </table>
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 537          5.0     78.0           48.0            0.0      0.0  33.700001
# 538          2.0     98.0           60.0           17.0    120.0  34.700001
# 539          6.0    114.0           88.0            0.0      0.0  27.799999
# 540          1.0    143.0           74.0           22.0     61.0  26.200001
# 541         10.0    122.0           78.0           31.0      0.0  27.600000
# ..           ...      ...            ...            ...      ...        ...
# 763          2.0    157.0           74.0           35.0    440.0  39.400002
# 764          2.0     92.0           52.0            0.0      0.0  30.100000
# 765         12.0    100.0           84.0           33.0    105.0  30.000000
# 766          2.0    114.0           68.0           22.0      0.0  28.700001
# 767         11.0    111.0           84.0           40.0      0.0  46.799999
#
#      DiabetesPedigreeFunction   Age  Outcome  prediction_label  \
# 537                     0.654  25.0        0                 0
# 538                     0.198  22.0        0                 0
# 539                     0.247  66.0        0                 0
# 540                     0.256  21.0        0                 0
# 541                     0.512  45.0        0                 0
# ..                        ...   ...      ...               ...
# 763                     0.134  30.0        0                 1
# 764                     0.141  22.0        0                 0
# 765                     0.488  46.0        0                 0
# 766                     0.092  25.0        0                 0
# 767                     0.925  45.0        1                 1
#
#      prediction_score
# 537            0.8745
# 538            0.8921
# 539            0.7672
# 540            0.7841
# 541            0.5039
# ..                ...
# 763            0.5329
# 764            0.9321
# 765            0.6177
# 766            0.8779
# 767            0.7895
#
# [231 rows x 11 columns]

# %%
predict_model(best_model, df.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_78c79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c79_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_78c79_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_78c79_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_78c79_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_78c79_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_78c79_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_78c79_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_78c79_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78c79_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_78c79_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_78c79_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_78c79_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_78c79_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_78c79_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_78c79_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_78c79_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0         10.0    101.0           76.0           48.0    180.0  32.900002
# 1          2.0    122.0           70.0           27.0      0.0  36.799999
# 2          5.0    121.0           72.0           23.0    112.0  26.200001
# 3          1.0    126.0           60.0            0.0      0.0  30.100000
# 4          1.0     93.0           70.0           31.0      0.0  30.400000
#
#    DiabetesPedigreeFunction   Age  Outcome  prediction_label  prediction_score
# 0                     0.171  63.0        0                 0            0.6019
# 1                     0.340  27.0        0                 0            0.7147
# 2                     0.245  30.0        0                 0            0.7957
# 3                     0.349  47.0        1                 0            0.7631
# 4                     0.315  23.0        0                 0            0.9303

# %%
predict_model(best_model, df.drop("Outcome", axis = 1).tail())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0         10.0    101.0           76.0           48.0    180.0  32.900002
# 1          2.0    122.0           70.0           27.0      0.0  36.799999
# 2          5.0    121.0           72.0           23.0    112.0  26.200001
# 3          1.0    126.0           60.0            0.0      0.0  30.100000
# 4          1.0     93.0           70.0           31.0      0.0  30.400000
#
#    DiabetesPedigreeFunction   Age  prediction_label  prediction_score
# 0                     0.171  63.0                 0            0.6019
# 1                     0.340  27.0                 0            0.7147
# 2                     0.245  30.0                 0            0.7957
# 3                     0.349  47.0                 0            0.7631
# 4                     0.315  23.0                 0            0.9303

# %%
save_model(best_model, model_name = "logistic-regression-model")
# saves as pickle file
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/var/folders/36/2yr7cfr96b983psr0fv9b4w00000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'SkinThickness',
#                                               'Insulin', 'BMI',
#                                               'DiabetesPedigreeFunction',
#                                               'Age'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values...
#                                                                fill_value='constant',
#                                                                missing_values=nan,
#                                                                strategy='constant',
#                                                                verbose='deprecated'))),
#                  ('low_variance',
#                   TransformerWrapper(exclude=[], include=None,
#                                      transformer=VarianceThreshold(threshold=0))),
#                  ('trained_model',
#                   LinearDiscriminantAnalysis(covariance_estimator=None,
#                                              n_components=None, priors=None,
#                                              shrinkage=None, solver='svd',
#                                              store_covariance=False,
#                                              tol=0.0001))],
#           verbose=False),
#  'logistic-regression-model.pkl')

# %%
trained_model_diabetes = load_model("logistic-regression-model")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
#model = load_model("logistic-regression-model")
predict_model(trained_model_diabetes, df.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_322d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_322d9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_322d9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_322d9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_322d9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_322d9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_322d9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_322d9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_322d9_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_322d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_322d9_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_322d9_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_322d9_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_322d9_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_322d9_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_322d9_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_322d9_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_322d9_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0         10.0    101.0           76.0           48.0    180.0  32.900002
# 1          2.0    122.0           70.0           27.0      0.0  36.799999
# 2          5.0    121.0           72.0           23.0    112.0  26.200001
# 3          1.0    126.0           60.0            0.0      0.0  30.100000
# 4          1.0     93.0           70.0           31.0      0.0  30.400000
#
#    DiabetesPedigreeFunction   Age  Outcome  prediction_label  prediction_score
# 0                     0.171  63.0        0                 0            0.6019
# 1                     0.340  27.0        0                 0            0.7147
# 2                     0.245  30.0        0                 0            0.7957
# 3                     0.349  47.0        1                 0            0.7631
# 4                     0.315  23.0        0                 0            0.9303
